# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# IF NEED TO RESET DURING TESTING.
# Drop if need to refresh from Json then import e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# db.establishments.drop()

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6475fc12cf4e2e79d78d362e'),
#  'geocode': {'latitude': '51.085797', 'longitude': '1.194762'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']
pprint(establishments)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
add_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

pprint(add_restaurant)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Check if objectID is already in collection
pprint(establishments.find_one({"AddressLine1":add_restaurant['AddressLine1']}))
# Out:
# None

# %%
# Insert the new restaurant into the collection
if establishments.find_one({"AddressLine1":add_restaurant["AddressLine1"]}) == None:
    # Insert the new data into the collection
    establishments.insert_one(add_restaurant)
    
    # Print objectID when inserted
    print(f'Adding object with AddressLine1: {add_restaurant["AddressLine1"]}')
# Out:
# Adding object with AddressLine1: Penang Flavours

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one({"AddressLine1":add_restaurant['AddressLine1']}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6475fc2b19d309233fda1000'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields

# Query
query = {'BusinessType': "Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID', 'BusinessType'}
sort = [('measurements.elementMeasurements.Height', -1)]
limit = 10

# Cast the results as a list and save them to a variable
results = list(establishments.find(query, fields).sort(sort).limit(limit))

# Pretty print the results
pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3360')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3364')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3352')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d335c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3355')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3351')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d334e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d334d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3350')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6475fc12cf4e2e79d78d3357')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Created or Switched to collection
# names: establishments
collection = db.establishments

# Updating AddfressLine1 = Penange Flavors
filter = { 'AddressLine1': 'Penang Flavours' }

# Values to be updated.
newvalues = { "$set": { 'BusinessTypeID': 1 } }

# Using update_one() method for single
# updation.
collection.update_one(filter, newvalues)

# %%
# Confirm that the new restaurant was updated

# Printing the updated content of the
pprint(establishments.find_one({"AddressLine1":add_restaurant['AddressLine1']}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6475fc2b19d309233fda1000'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

# Build the aggregation pipeline
# Write a match query to find only the establishments where LocalAuthorityName is "Dover"
match_query = {'$match': {'LocalAuthorityName': {'$regex': "Dover"}
                         }
              }

# Write an aggregation query that counts the number of documents, grouped by "classification" and "culture"
group_query = {'$group': {'_id': {"classification": "$classification",
                                  "_id": "$_id", 
                                   "BusinessName": "$BusinessName"}, 
                          'count': { '$sum': 1 }
                         }
              }

# Create a dictionary that will allow the pipeline to sort by count in descending order
sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]

# %%
# Run the pipeline through the aggregate method, cast the results as a list, and save the results to a variable
results = list(establishments.aggregate(pipeline))
print("Number of Establishments where LocalAuthorityName is Dover in result: ", len(results))
# Out:
# Number of Establishments where LocalAuthorityName is Dover in result:  994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
# establishments.deleteMany( {'LocalAuthorityName': {'$regex': "Dover"}})

query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)

results_all = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3630'), 'BusinessName': 'Little Satmar Farm Holiday Complex'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3393'), 'BusinessName': "Wheeler's Fish & Chips"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3471'), 'BusinessName': 'The Flamin Chicken'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3618'), 'BusinessName': 'Golden River'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3457'), 'BusinessName': 'Dover Fish Bar'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3d9d'), 'BusinessName': 'Goodnestone Park'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3553'), 'BusinessName': "Welly's Coffeehouse and Bar"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3616'), 'BusinessName': 'Flo the Caravan'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33e9'), 'BusinessName': 'The Corner Cafe'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3446'), 'BusinessName': 'Dover College'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3e21'), 'BusinessName': 'Aylesham Fried Chicken'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35de'), 'BusinessName': 'The Cricketers'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d356a'), 'BusinessName': 'Ann and Pams Florist'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3507'), 'BusinessName': 'Westbank Guest House'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34e4'), 'BusinessName': 'Deal Centre For The Retired'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3406'), 'BusinessName': 'The Freed Man'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3505'), 'BusinessName': 'Treetops Pre School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3623'), 'BusinessName': 'Turning Point'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3460'), 'BusinessName': 'Pumpkin Cafe Shop'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3604'), 'BusinessName': 'Mcdonalds Drive Thru'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3799'), 'BusinessName': 'Busy Bees Pre-School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3f48'), 'BusinessName': 'Oakfield House'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d347b'), 'BusinessName': 'Zazen Kitchen'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d335f'), 'BusinessName': 'Seahaven & Kingsdown Lodge'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d379d'), 'BusinessName': 'Plough And Harrow'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34d6'), 'BusinessName': '81 Beach Street'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3c8a'), 'BusinessName': 'Staple Pre School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3f4d'), 'BusinessName': 'The Dog at Wingham'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33ce'), 'BusinessName': 'Pizza 2 Night'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3509'), 'BusinessName': 'Kaleidascope Childcare Ltd'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d366d'), 'BusinessName': 'Martha House'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3497'), 'BusinessName': 'Sea View'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3459'), 'BusinessName': 'Deal Parochial C Of E Aided Primary School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34a7'), 'BusinessName': 'Kings Coffee Shop'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d358f'), 'BusinessName': 'Ice Cream Van B30HW'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3d1e'), 'BusinessName': 'B And B Accommodation'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3493'), 'BusinessName': 'Louis Armstrong'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3582'), 'BusinessName': 'Betteshanger Social Welfare Sports C'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35a7'), 'BusinessName': 'SPN Minimart'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3504'), 'BusinessName': 'Goodwin Academy'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3408'), 'BusinessName': 'The Thompsons Bell'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3a03'), 'BusinessName': 'The New Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33ca'), 'BusinessName': 'MK Catering'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34cf'), 'BusinessName': 'Mild White'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33ad'), 'BusinessName': 'German Doner Kebab'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39c1'), 'BusinessName': 'Tan-Bueno'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35ca'), 'BusinessName': 'The Ambrette at The Three Cups Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3528'), 'BusinessName': 'Flints'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35b4'), 'BusinessName': 'The Plough'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3587'), 'BusinessName': "Daisy's Kitchen"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3557'), 'BusinessName': 'Chance Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34b7'), 'BusinessName': 'The Goodwin'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3c9e'), 'BusinessName': "Juliet's Farm Shop and Cafe"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3cf1'), 'BusinessName': 'Cartwright & Kelsey Breakfast Club'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35ad'), 'BusinessName': 'Twyford House Residential Home'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3421'), 'BusinessName': 'Dovorian'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d399f'), 'BusinessName': 'St Barts Day Nurseries Out Of School Centre'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3561'), 'BusinessName': 'Clay Pigeon Club'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d347f'), 'BusinessName': 'Homeleigh Residential Care'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d342d'), 'BusinessName': "Amarillo's"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d37a1'), 'BusinessName': 'St Crispin Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d357a'), 'BusinessName': 'Breakwater Tap House and Pizzeria'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3636'), 'BusinessName': 'The Fox Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3a0f'), 'BusinessName': 'S and C Baitup Family Butcher'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3391'), 'BusinessName': 'Costa Coffee, Next'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d356b'), 'BusinessName': 'Nirja Convenience Store'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3e5f'), 'BusinessName': 'The Frog And Orange'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d361a'), 'BusinessName': 'Whitfield Care Home'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34ca'), 'BusinessName': 'Poundland'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3376'), 'BusinessName': 'Adventure Backpackers Hostel'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3
}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33f4'), 'BusinessName': 'Subway'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3e46'), 'BusinessName': "Hill'z treats"}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d335a'), 'BusinessName': 'Lenox House'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33ba'), 'BusinessName': 'Aspendos'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3f9f'), 'BusinessName': 'Get Prepped'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3b1f'), 'BusinessName': 'Subway'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3812'), 'BusinessName': 'Promis Clinic'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39bd'), 'BusinessName': 'The Sandwich Bakery Company'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33dc'), 'BusinessName': 'Dover Convenience Store'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34f8'), 'BusinessName': 'Miretti Pasticceria'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3617'), 'BusinessName': 'TukTuk WF&Co'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33d9'), 'BusinessName': 'The Attic Bar'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34f3'), 'BusinessName': 'S.Mart Offlicense & Convenience'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d353f'), 'BusinessName': 'Little India'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3a1f'), 'BusinessName': 'Co-op'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d336f'), 'BusinessName': 'Hogbox'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3527'), 'BusinessName': 'Total Fitness Mix Ltd'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35b9'), 'BusinessName': 'Buckland Court'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3900'), 'BusinessName': 'The Crown Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3a47'), 'BusinessName': 'Sandwich Infant School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3cf2'), 'BusinessName': 'Fledglings Nursery'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3545'), 'BusinessName': 'Kong Sing'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3adf'), 'BusinessName': 'Co-op'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3502'), 'BusinessName': 'Felbrigg House Residential Home'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3417'), 'BusinessName': 'Brunch Cafe Limited'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3411'), 'BusinessName': 'Biggin Off Licence'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3d94'), 'BusinessName': 'Bennett & Friends Catering + Events'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3600'), 'BusinessName': 'Boost Kitchen'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d341f'), 'BusinessName': 'Goose on the Green'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3378'), 'BusinessName': 'Loddington House Hotel'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d345f'), 'BusinessName': 'Dover Food & Wine'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35c1'), 'BusinessName': 'Elms School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35a2'), 'BusinessName': 'Bull Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33f0'), 'BusinessName': 'Downs Sailing Club'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d338a'), 'BusinessName': 'Royal Cinque Ports Yacht Club'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3560'), 'BusinessName': 'Oriental Express'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3d9b'), 'BusinessName': 'The Old Dairy'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3bf3'), 'BusinessName': 'Griffins Head'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35af'), 'BusinessName': 'Coombe Valley Food and Wine'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33df'), 'BusinessName': 'St Marys Parish Centre'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33ef'), 'BusinessName': 'Sunnycroft Bed & Breakfast'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3622'), 'BusinessName': 'Track Snacks'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3595'), 'BusinessName': 'Ice Cream Van N168 XVN'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3431'), 'BusinessName': 'Thong Dees Thai'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d357e'), 'BusinessName': 'League Of Friends Of Dover Hospitals'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3988'), 'BusinessName': 'Shanghai'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d396c'), 'BusinessName': 'Stonar Cafe'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d37e7'), 'BusinessName': 'Principals by CH&Co @'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3cd2'), 'BusinessName': 'The Volunteer PH'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34a2'), 'BusinessName': 'Roosters Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d37e6'), 'BusinessName': 'Northbourne Park School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33e5'), 'BusinessName': 'Cafe Melange'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34e9'), 'BusinessName': 'The Black Pig'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34d3'), 'BusinessName': 'Smugglers Records'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3500'), 'BusinessName': 'Arno & Co'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d354f'), 'BusinessName': 'The Mill Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35eb'), 'BusinessName': 'Tesco Family Dining Ltd'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d346f'), 'BusinessName': 'Baba Food and Wine'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33b1'), 'BusinessName': 'Rico Sabor'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3559'), 'BusinessName': 'Deal Christian Fellowship Trust'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39b4'), 'BusinessName': 'Crispin Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35ab'), 'BusinessName': 'Crabble post office'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d354c'), 'BusinessName': 'Next Steps Pre-school'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3476'), 'BusinessName': 'HEY! Sushi'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33f3'), 'BusinessName': 'The Drum Major'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34af'), 'BusinessName': 'Clare House'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3983'), 'BusinessName': 'Eythorne Station Tea Room'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35e4'), 'BusinessName': 'Dover Transport Museum'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3cb0'), 'BusinessName': 'The Chequer Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3492'), 'BusinessName': 'The Lane'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33e4'), 'BusinessName': 'La Salle Verte'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34c5'), 'BusinessName': 'Cabin Bar, The Clarendon Hotel'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d351d'), 'BusinessName': 'Top Wok'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d360e'), 'BusinessName': 'Christian Centre'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d36da'), 'BusinessName': 'Northbourne County Primary School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3359'), 'BusinessName': 'The Village Shop'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33c7'), 'BusinessName': 'Greggs'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3366'), 'BusinessName': 'Kingsdown Newsagents'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d379c'), 'BusinessName': 'Chilton Villa B & B'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39d9'), 'BusinessName': 'Bella Amalfi'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3f55'), 'BusinessName': 'Dog And Duck Inn'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d348d'), 'BusinessName': 'Luscious Chinese Takeaway'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39f4'), 'BusinessName': 'Mermaids Locker'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d337c'), 'BusinessName': 'Dunkerque Seaways'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d39cd'), 'BusinessName': 'Five Bells'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35d8'), 'BusinessName': 'Home Bargains'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc13cf4e2e79d78d3f49'), 'BusinessName': 'Covert Cafe'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35b0'), 'BusinessName': 'Pit Stop Snack Bar Unit 1'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35c5'), 'BusinessName': 'Sunny Corner Pre-School'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35fe'), 'BusinessName': 'Rajmahal'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3637'), 'BusinessName': 'Hare And Hounds'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d358b'), 'BusinessName': 'King Edward Store'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d35df'), 'BusinessName': 'Subway'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34bc'), 'BusinessName': 'Sir Norman Wisdom'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3993'), 'BusinessName': 'Namaste Sandwich'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3365'), 'BusinessName': 'The Tea Room'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3480'), 'BusinessName': 'Golden Grill Fish Bar'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3b22'), 'BusinessName': 'Kfc'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3506'), 'BusinessName': 'Kent Museum of the Moving Image'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d34fa'), 'BusinessName': 'Peppers Healthfoods'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d33b5'), 'BusinessName': 'Dover kebab house'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d347a'), 'BusinessName': 'Deal Victoria And Barnes Close Cc'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3a27'), 'BusinessName': 'Java Restaurant'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3584'), 'BusinessName': 'Astor College'}, 'count': 1}
# {'_id': {'_id': ObjectId('6475fc12cf4e2e79d78d3dce'), 'BusinessName': 'Aylesham Cafe'}, 'count': 1}

# %%
# Check if any remaining documents include Dover
# method 1
results_new = list(establishments.aggregate(pipeline))
print("Number of Establishments where LocalAuthorityName is Dover in result: ", len(results_new))


# method 2
# dover_count = establishments.count_documents({'db.establishments.LocalAuthorityName': {'$regex': 'Dover'}})
# dover_count
# Out:
# Number of Establishments where LocalAuthorityName is Dover in result:  0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6475fc12cf4e2e79d78d362e'),
#  'geocode': {'latitude': '51.085797', 'longitude': '1.194762'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude

# establishments
establishments.update_many({}, [{'$set' : {'geocode.longitude' : {'$toDouble': '$geocode.longitude'},
                                       'geocode.latitude' : {'$toDouble': '$geocode.latitude'}
                                      }
                                }]
                          )

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [{'$set' : {'geocode.latitude' : {'$toDouble': '$geocode.latitude'},
                                       'geocode.latitude' : {'$toDouble': '$geocode.latitude'}
                                      }
                                }]
                          )

# %%
# Check that the coordinates are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6475fc12cf4e2e79d78d362e'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
